# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import sklearn
from sklearn.cluster import DBSCAN

# %%
data = pd.read_csv('./data/ktw_modified.csv') #wczytanie danych

# %%
data.set_index(keys=['Rok','Miesiac','Dzien'], inplace = True) #ustawienie multiindeksu na rok-miesiac-dzien

# %%
data.sort_index(inplace = True) #sortowanie po indeksie

# %%
data['Typ_opadu'] = data['Typ_opadu'].round(0).astype(int) #zaokrąglenie i rzutowanie na int

# %%
data #wyswietlenie gotowych danych
# Out:
#                     Tmax  Tmin  Tmin_grunt  Opad  Typ_opadu
# Rok  Miesiac Dzien
# 2001 1       1      -0.7  -7.9       -11.1   0.0          1
#              2       2.4  -8.7        -8.1   0.1          1
#              3       2.2  -3.4        -5.1   5.6          1
#              4       6.1   0.5        -2.7   0.0          1
#              5       6.5  -1.9        -2.8   0.2          1
# ...                  ...   ...         ...   ...        ...
# 2019 12      27      2.7   1.4         0.6   0.6          2
#              28      1.5  -1.6        -1.6   0.3          2
#              29     -0.1  -1.8        -1.8   0.0          2
#              30      3.1  -4.9        -6.1   0.0          2
#              31      4.8   2.0         0.4   0.0          0
#
# [6939 rows x 5 columns]

# %%
tmax = pd.Series(data.Tmax)
tmin = pd.Series(data.Tmin)

# %%
fullt = tmax.append(tmin, ignore_index=False)

# %%
fullt #bierzemy całą temperaturę i zobaczymy co wyjdzie
# Out:
# Rok   Miesiac  Dzien
# 2001  1        1       -0.7
#                2        2.4
#                3        2.2
#                4        6.1
#                5        6.5
#                        ...
# 2019  12       27       1.4
#                28      -1.6
#                29      -1.8
#                30      -4.9
#                31       2.0
# Length: 13878, dtype: float64

# %%
A = fullt.values.reshape(-1,1)

# %%
model = DBSCAN(eps = 0.4, min_samples = 8).fit(A)
#dwa najważniejsze parametry tego modelu to:
#epsilion - maksymalny dystans między dwoma punktami
#min_samples - minimalna liczba punktów w sąsiedztwie
#trzeba odpowiednio dobrać parametry do danych

# %%
model
# Out:
# DBSCAN(algorithm='auto', eps=0.4, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=8, n_jobs=None, p=None)

# %%
con = model.labels_ == -1 #model zwraca -1 jesli dany punkt jest outlierem

# %%
outliers = pd.Series(fullt[con])

# %%
outliers.sort_index(inplace = True)

# %%
outliers #outliery wyglądają dobrze
# w przeciwieństwie do metod statystycznych znaleziono też outliery w tmax
# Out:
# Rok   Miesiac  Dzien
# 2002  1        4       -23.8
#       12       26      -19.9
# 2003  1        9       -20.6
#       2        13      -20.3
# 2006  1        22      -20.2
#                23      -26.8
#                24      -24.9
#                25      -20.9
#       2        5       -19.7
# 2010  1        23      -19.6
#                24      -21.4
#                25      -20.0
#                27      -21.2
#       12       5       -20.7
# 2012  2        2       -20.2
#                3       -23.3
#                4       -22.1
#                11      -22.6
#                12      -22.4
# 2013  7        29       35.4
#       8        8        37.2
# 2017  1        7       -26.0
#                8       -24.7
#                9       -21.0
# 2019  7        1        35.2
# dtype: float64

# %%
#WYKRES KLASTROW

# %%
core_samples_mask = np.zeros_like(model.labels_, dtype=bool)
core_samples_mask[model.core_sample_indices_] = True

# %%
lab = model.labels_
uniqlab = set(lab)
colors = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(uniqlab))]

# %%
for l, c in zip(uniqlab, colors):
    if l == -1:
        c = [0, 0, 0, 1]
    
    class_member_mask = (lab == l)
    xy = A[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 0], 'o', markerfacecolor=tuple(c), markeredgecolor='k', markersize=10)
    xy = A[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 0], 'o', markerfacecolor=tuple(c), markeredgecolor='k', markersize=5)
    plt.rcParams["figure.figsize"] = (20,15)

# %%
#teraz grupowanie i outliery według miesięcy

# %%
B = fullt.reset_index()
B.set_index(['Rok','Dzien'],inplace=True)

# %%
names = {0:'Temperatura'}
B.rename(columns=names, inplace=True)

# %%
B
# Out:
#             Miesiac  Temperatura
# Rok  Dzien
# 2001 1            1         -0.7
#      2            1          2.4
#      3            1          2.2
#      4            1          6.1
#      5            1          6.5
# ...             ...          ...
# 2019 27          12          1.4
#      28          12         -1.6
#      29          12         -1.8
#      30          12         -4.9
#      31          12          2.0
#
# [13878 rows x 2 columns]

# %%
model2 = DBSCAN(eps = 0.8, min_samples = 5).fit(B)

# %%
model2
# Out:
# DBSCAN(algorithm='auto', eps=0.8, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
con2 = model2.labels_ == -1 #model zwraca -1 jesli dany punkt jest outlierem

# %%
outliers2 = B.loc[con2,['Miesiac','Temperatura']]

# %%
outliers2.reset_index(inplace=True)

# %%
outliers2.set_index(['Rok','Miesiac','Dzien'], inplace=True)

# %%
outliers2.sort_index()
# Out:
#                     Temperatura
# Rok  Miesiac Dzien
# 2001 10      3             26.6
#      11      27            -8.8
# 2002 1       4            -23.8
#      4       7             -8.2
#      9       30            -0.8
#      12      26           -19.9
# 2003 2       13           -20.3
#      10      25            -6.9
#              28            -6.6
#              29            -6.4
# 2004 3       6            -17.4
# 2005 3       1            -13.2
#              3            -13.8
#      5       30            32.2
# 2006 1       23           -26.8
#              24           -24.9
#      2       5            -19.7
#      12      6             15.3
#              9             16.4
# 2007 5       2             -2.8
#      11      18            -8.9
#              29            -9.1
# 2008 2       24            16.0
# 2010 11      30            -9.7
#      12      5            -20.7
#              17           -19.1
# 2011 9       5             30.9
# ...

# %%
#WYKRES

# %%
core_samples_mask2 = np.zeros_like(model2.labels_, dtype=bool)
core_samples_mask2[model2.core_sample_indices_] = True

# %%
lab2 = model2.labels_
uniqlab2 = set(lab2)
colors2 = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(uniqlab2))]

# %%
for n, col in zip(uniqlab2, colors2):
    if n == -1:
        col = [0, 0, 0, 1]
    
    class_member_mask2 = (lab2 == n)
    xy2 = B[class_member_mask2 & core_samples_mask2]
    plt.plot(xy2.iloc[:, 0], xy2.iloc[:, 1], 'o', markerfacecolor=tuple(col), markeredgecolor='k', markersize=10)
    xy2 = B[class_member_mask2 & ~core_samples_mask2]
    plt.plot(xy2.iloc[:, 0], xy2.iloc[:, 1], 'o', markerfacecolor=tuple(col), markeredgecolor='k', markersize=5)
    plt.rcParams["figure.figsize"] = (20,15)

# %%
#grupowanie razem tmax i tmin

# %%
C = data[['Tmax','Tmin']]

# %%
C
# Out:
#                     Tmax  Tmin
# Rok  Miesiac Dzien
# 2001 1       1      -0.7  -7.9
#              2       2.4  -8.7
#              3       2.2  -3.4
#              4       6.1   0.5
#              5       6.5  -1.9
# ...                  ...   ...
# 2019 12      27      2.7   1.4
#              28      1.5  -1.6
#              29     -0.1  -1.8
#              30      3.1  -4.9
#              31      4.8   2.0
#
# [6939 rows x 2 columns]

# %%
model3 = DBSCAN(eps = 0.9, min_samples = 3).fit(C)

# %%
model3
# Out:
# DBSCAN(algorithm='auto', eps=0.9, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=3, n_jobs=None, p=None)

# %%
con3 = model3.labels_ == -1 #model zwraca -1 jesli dany punkt jest outlierem

# %%
outliers3 = C.loc[con3,['Tmax','Tmin']]

# %%
outliers3.sort_index()
# Out:
#                     Tmax  Tmin
# Rok  Miesiac Dzien
# 2001 5       24     23.9   2.7
# 2002 1       4     -10.6 -23.8
#              5      -3.8 -19.1
#      12      25     -9.5 -17.7
# 2003 1       2       4.4 -14.4
#      2       14     -2.1 -16.9
#              24      7.6 -12.0
#              25      7.6  -9.7
#              26      8.8  -9.6
#      5       6      29.1   6.9
# 2004 3       6       0.8 -17.4
# 2005 2       8       2.1 -18.1
# 2006 1       9      -0.4 -16.5
#              22      0.9 -20.2
#              23    -17.3 -26.8
#              24    -10.6 -24.9
#              25     -6.2 -20.9
#              29     -1.0 -17.3
# 2009 4       3      20.4  -0.9
#      12      19    -11.5 -17.3
#              20    -12.3 -16.4
#              22      5.3 -11.6
# 2010 1       23     -9.9 -19.6
#              25     -7.7 -20.0
#      12      29     -8.9 -12.2
# 2011 1       6       3.8 -15.5
#      8       27     32.1  22.0
# 2012 2       1     -10.8 -17.2
# ...

# %%
#WYKRES

# %%
core_samples_mask3 = np.zeros_like(model3.labels_, dtype=bool)
core_samples_mask3[model3.core_sample_indices_] = True

# %%
lab3 = model3.labels_
uniqlab3 = set(lab3)
colors3 = [plt.cm.Spectral(each) for each in np.linspace(0, 1, len(uniqlab3))]

# %%
for k, co in zip(uniqlab3, colors3):
    if k == -1:
        co = [0, 0, 0, 1]
    
    class_member_mask3 = (lab3 == k)
    xy3= C[class_member_mask3 & core_samples_mask3]
    plt.plot(xy3.iloc[:, 0], xy3.iloc[:, 1], 'o', markerfacecolor=tuple(co), markeredgecolor='k', markersize=10)
    xy3 = C[class_member_mask3 & ~core_samples_mask3]
    plt.plot(xy3.iloc[:, 0], xy3.iloc[:, 1], 'o', markerfacecolor=tuple(co), markeredgecolor='k', markersize=5)
    plt.rcParams["figure.figsize"] = (20,15)
